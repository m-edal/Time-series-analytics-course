# %%
if 'google.colab' in str(get_ipython()):
    
    # Mount the Google Drive at mount
    from google.colab import drive
    mount='/content/gdrive'
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Switch to the directory on the Google Drive that you want to use
    import os
    from os import path
    
    drive_root = mount + "/My Drive/Colab Notebooks/MPEC/Time-series-analytics-course"
    # Change to the directories to get data files
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
        
    # !pip install shap
    # !pip install ruptures
else:
    print("not working in Google Colab!")

# %%
import pandas as pd
import glob

# %% [markdown]
# # Import site data

# %% [markdown]
# Now we will read the hourly pollutant data from the Manchester site of the Automatic Urban and Rural Network (AURN). From the imported files, we can understand the basic information of each site, such as monitoring time, types of pollutants, site name, site type, site location, etc. Each site is also automatically matched with meteorological data from both the monitoring network itself and the ECMWF ERA5 re-analysis.
#
#     *The meteorological parameters from sites are: wind speed (ws, m/s), wind direction (wd, °), temperature (temp, ℃).
#
#     *The meteorological parameters from ERA5 re-analysis dataset are: 10m u-component of wind (u10, m/s), 10m v-component of wind (v10, m/s), 2m temperature (t2m, ℃), boundary layer height (blh, m), surface pressure (sp, hPa), surface solar radiation downwards (ssrd, J/m2), total rainfall (tp, m), relative humidity (r, %).

# %%
station_files=glob.glob('./data/AutoML/*.csv')
example_station=pd.read_csv(station_files[2])
example_station
# Out:
#                    date        O3        NO       NO2  NOXasNO2      SO2  CO  \
# 0      25/11/2010 00:00  28.00000   5.00000  36.00000  44.00000      NaN NaN
# 1      25/11/2010 02:00  42.00000   3.00000  23.00000  27.00000      NaN NaN
# 2      25/11/2010 03:00  46.00000   3.00000  21.00000  25.00000      NaN NaN
# 3      25/11/2010 04:00  46.00000   3.00000  23.00000  27.00000      NaN NaN
# 4      25/11/2010 05:00  44.00000   3.00000  25.00000  29.00000      NaN NaN
# ...                 ...       ...       ...       ...       ...      ...  ..
# 99371  05/11/2023 19:00   7.14197  15.15972  51.58684  74.83143  1.15989 NaN
# 99372  05/11/2023 20:00   7.19733  12.37396  45.26753  64.24067  0.96658 NaN
# 99373  05/11/2023 21:00   9.30117   9.16710  42.47776  56.53378  0.83770 NaN
# 99374  05/11/2023 22:00  13.89639   6.54330  37.00398  47.03690  0.77326 NaN
# 99375  05/11/2023 23:00  26.18722   2.42944  19.94252  23.66761  0.57995 NaN
#
#          PM10                   site  code  ...         Ox       u10  \
# 0         NaN  Manchester Piccadilly  MAN3  ...  31.737663  1.152269
# 1         NaN  Manchester Piccadilly  MAN3  ...  31.948125  1.051118
# 2         NaN  Manchester Piccadilly  MAN3  ...  32.874158  1.120659
# 3         NaN  Manchester Piccadilly  MAN3  ...  33.884375  1.234453
# 4         NaN  Manchester Piccadilly  MAN3  ...  33.926467  1.453191
# ...       ...                    ...   ...  ...        ...       ...
# 99371  41.700  Manchester Piccadilly  MAN3  ...  29.514121  1.882244
# 99372  46.950  Manchester Piccadilly  MAN3  ...  26.348981  1.404501
# 99373  35.700  Manchester Piccadilly  MAN3  ...  25.958234  1.031469
# 99374  22.025  Manchester Piccadilly  MAN3  ...  25.417753  0.169242
# 99375  13.025  Manchester Piccadilly  MAN3  ...  22.749391  0.287042
#
#             v10         d2m         t2m         blh           sp   ssrd  \
# 0     -2.325125  270.189941  271.543427  313.178223  99113.98438  0.000
# 1     -2.578859  269.913361  271.170105  369.558472  99079.18750  0.000
# 2     -2.446536  269.555878  270.866363  363.322510  99062.98438  0.000
# 3     -2.144374  269.149322  270.481171  359.264770  99053.21875  0.000
# 4     -1.872223  268.833893  270.126801  330.519409  99054.88281  0.000
# ...         ...         ...         ...         ...          ...    ...
# 99371  1.775450  279.260590  280.760864  231.899780  97078.70313  0.125
# 99372  2.025538  279.316894  280.508942  189.056885  97133.26563  0.125
# 99373  2.418028  278.974487  280.085693  179.768921  97167.72656  0.125
# 99374  2.350724  278.566101  279.483948  137.654541  97201.53125  0.125
# 99375  2.789973  278.804443  279.728699  171.072876  97230.68750  0.125
#
#                  tp          r
# 0     -4.660000e-10  83.760262
# 1     -4.660000e-10  81.644234
# 2     -4.660000e-10  81.059067
# 3     -4.660000e-10  80.167725
# 4     -4.660000e-10  80.222076
# ...             ...        ...
# 99371  4.910000e-05  90.358765
# 99372  1.349760e-04  91.411278
# 99373  2.060000e-05  92.087143
# 99374  1.430000e-05  90.295990
# 99375  1.930000e-05  91.365250
#
# [99376 rows x 33 columns]

# %% [markdown]
# # Use automated machine learning (AutoML) to establish the regression model between concentration and meteorological parameters

# %% [markdown]
# FLAML (Fast and Lightweight AutoML,https://microsoft.github.io/FLAML/docs/getting-started) is an open-source, lightweight, and efficient automatic machine learning (AutoML) library designed to simplify the machine learning process. Developed by Microsoft, FLAML aims to make AutoML more accessible by providing fast and cost-effective solutions for model training and hyperparameter tuning without compromising accuracy.
# In this course, we will utilize the superior performance of FLAML to build regression models for pollutant concentrations and meteorological parameters. What are the steps?
#
#     *prepare the input data for AutoML
#     *import the FLAML package (if installed)
#     *set the target and parameters for AutoML parameters
#         -task type
#         -time budget of AutoML
#         -optimazation metric
#         -estimators used in this task

# %%
# load the site files and select the pollutant concentration and meteorological parameters. Here we use MAN3 as an example
MAN3_DATA=pd.read_csv(station_files[2])
print(MAN3_DATA.columns)
# Out:
# Index(['date', 'O3', 'NO', 'NO2', 'NOXasNO2', 'SO2', 'CO', 'PM10', 'site',
#        'code', 'latitude', 'longitude', 'location_type', 'NV10', 'V10',
#        'PM2.5', 'NV2.5', 'V2.5', 'wd', 'ws', 'temp', 'AT2.5', 'AP2.5', 'Ox',
#        'u10', 'v10', 'd2m', 't2m', 'blh', 'sp', 'ssrd', 'tp', 'r'],
#       dtype='object')

# %%
# select the pollutant and meteorological parameters
pollutant_met=['NO2','wd','ws','temp','blh','sp','ssrd','tp','r']
MAN3_DATA_ML=MAN3_DATA.loc[:,pollutant_met]
MAN3_DATA_ML
# Out:
#             NO2     wd   ws  temp         blh           sp   ssrd  \
# 0      36.00000  179.6  1.6  -0.3  313.178223  99113.98438  0.000
# 1      23.00000  351.5  3.2   0.5  369.558472  99079.18750  0.000
# 2      21.00000  353.9  3.1   0.4  363.322510  99062.98438  0.000
# 3      23.00000  351.9  3.0   0.3  359.264770  99053.21875  0.000
# 4      25.00000  347.3  2.8  -0.2  330.519409  99054.88281  0.000
# ...         ...    ...  ...   ...         ...          ...    ...
# 99371  51.58684  208.9  2.4   7.3  231.899780  97078.70313  0.125
# 99372  45.26753  209.5  2.8   7.2  189.056885  97133.26563  0.125
# 99373  42.47776  209.3  2.8   7.1  179.768921  97167.72656  0.125
# 99374  37.00398  203.3  3.0   6.5  137.654541  97201.53125  0.125
# 99375  19.94252  204.8  3.4   6.9  171.072876  97230.68750  0.125
#
#                  tp          r
# 0     -4.660000e-10  83.760262
# 1     -4.660000e-10  81.644234
# 2     -4.660000e-10  81.059067
# 3     -4.660000e-10  80.167725
# 4     -4.660000e-10  80.222076
# ...             ...        ...
# 99371  4.910000e-05  90.358765
# 99372  1.349760e-04  91.411278
# 99373  2.060000e-05  92.087143
# 99374  1.430000e-05  90.295990
# 99375  1.930000e-05  91.365250
#
# [99376 rows x 9 columns]

# %%
# prepare the training and test dataset for AutoML
from sklearn.model_selection import train_test_split
y=MAN3_DATA_ML.loc[:,['NO2']].values
X1=MAN3_DATA_ML.loc[:,pollutant_met[1:]]
X=X1.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from flaml import AutoML

# set the parameters for AutoML
automl = AutoML()
automl_settings = {
            "time_budget": 20,
            "metric": 'r2',
            "task": 'regression',
            "estimator_list": ["lgbm", "rf", "xgboost", "extra_tree", "xgb_limitdepth", 'catboost'],
            'seed': 7654321
        }

# %% [markdown]
# "lgbm": Light Gradient Boosting Machine
# "rf": Random Forest
# "xgboost": Extreme Gradient Boosting
# "extra_tree": Extra Trees
# "xgb_limitdepth": Extreme Gradient Boosting with Limited Depth
# "catboost": Categorical Boosting

# %%
# run the AutoML
automl.fit(X_train=X_train, y_train=y_train, **automl_settings)
# Out:
# [flaml.automl.logger: 05-23 19:03:01] {1693} INFO - task = regression
# [flaml.automl.logger: 05-23 19:03:01] {1700} INFO - Data split method: uniform
# [flaml.automl.logger: 05-23 19:03:01] {1703} INFO - Evaluation method: holdout
# [flaml.automl.logger: 05-23 19:03:01] {1801} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 05-23 19:03:01] {1911} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'catboost']
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2347} INFO - Estimated sufficient time budget=981s. Estimated necessary time budget=8s.
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.0s,	estimator lgbm's best error=0.8870,	best estimator lgbm's best error=0.8870
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.1s,	estimator lgbm's best error=0.8870,	best estimator lgbm's best error=0.8870
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.1s,	estimator lgbm's best error=0.6459,	best estimator lgbm's best error=0.6459
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.1s,	estimator lgbm's best error=0.6061,	best estimator lgbm's best error=0.6061
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.1s,	estimator xgboost's best error=2.3489,	best estimator lgbm's best error=0.6061
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.1s,	estimator xgboost's best error=2.3489,	best estimator lgbm's best error=0.6061
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.3s,	estimator lgbm's best error=0.6061,	best estimator lgbm's best error=0.6061
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.4s,	estimator lgbm's best error=0.5769,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.4s,	estimator xgboost's best error=0.6408,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.5s,	estimator xgboost's best error=0.6135,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.5s,	estimator extra_tree's best error=0.8262,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.5s,	estimator extra_tree's best error=0.8145,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.5s,	estimator rf's best error=0.7857,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.6s,	estimator rf's best error=0.7662,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.6s,	estimator xgboost's best error=0.6135,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.6s,	estimator xgboost's best error=0.6135,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.7s,	estimator lgbm's best error=0.5769,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.7s,	estimator extra_tree's best error=0.8145,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.8s,	estimator lgbm's best error=0.5769,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:01] {2394} INFO -  at 0.9s,	estimator xgboost's best error=0.6040,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:01] {2221} INFO - iteration 20, current learner catboost
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.2s,	estimator catboost's best error=0.5924,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.2s,	estimator rf's best error=0.7662,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.3s,	estimator xgboost's best error=0.6040,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.3s,	estimator lgbm's best error=0.5769,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.6s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 25, current learner catboost
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.9s,	estimator catboost's best error=0.5902,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:02] {2394} INFO -  at 1.9s,	estimator extra_tree's best error=0.7637,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:02] {2221} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:03] {2394} INFO -  at 2.0s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:03] {2221} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:03] {2394} INFO -  at 2.0s,	estimator extra_tree's best error=0.7637,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:03] {2221} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:03] {2394} INFO -  at 2.0s,	estimator extra_tree's best error=0.7321,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:03] {2221} INFO - iteration 30, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:03] {2394} INFO -  at 2.0s,	estimator extra_tree's best error=0.7321,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:03] {2221} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:03] {2394} INFO -  at 2.8s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:03] {2221} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:04] {2394} INFO -  at 2.9s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:04] {2221} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:04] {2394} INFO -  at 3.6s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:04] {2221} INFO - iteration 34, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:04] {2394} INFO -  at 3.7s,	estimator extra_tree's best error=0.6928,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:04] {2221} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.6s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.6s,	estimator extra_tree's best error=0.6928,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.6s,	estimator extra_tree's best error=0.6666,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.6s,	estimator extra_tree's best error=0.6666,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 39, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.7s,	estimator extra_tree's best error=0.6338,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.7s,	estimator extra_tree's best error=0.6338,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.7s,	estimator extra_tree's best error=0.6338,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 42, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.7s,	estimator extra_tree's best error=0.6298,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 43, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.8s,	estimator xgb_limitdepth's best error=0.6162,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.8s,	estimator rf's best error=0.7024,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 45, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:05] {2394} INFO -  at 4.8s,	estimator xgb_limitdepth's best error=0.6162,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:05] {2221} INFO - iteration 46, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:06] {2394} INFO -  at 5.0s,	estimator xgb_limitdepth's best error=0.6162,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:06] {2221} INFO - iteration 47, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:06] {2394} INFO -  at 5.1s,	estimator xgb_limitdepth's best error=0.5978,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:06] {2221} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 05-23 19:03:06] {2394} INFO -  at 5.2s,	estimator rf's best error=0.7024,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:06] {2221} INFO - iteration 49, current learner extra_tree
# [flaml.automl.logger: 05-23 19:03:06] {2394} INFO -  at 5.3s,	estimator extra_tree's best error=0.6286,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:06] {2221} INFO - iteration 50, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:06] {2394} INFO -  at 5.4s,	estimator lgbm's best error=0.5304,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:06] {2221} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 05-23 19:03:06] {2394} INFO -  at 5.4s,	estimator rf's best error=0.6688,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:06] {2221} INFO - iteration 52, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:07] {2394} INFO -  at 6.0s,	estimator xgb_limitdepth's best error=0.5627,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:07] {2221} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 05-23 19:03:07] {2394} INFO -  at 6.0s,	estimator rf's best error=0.6688,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:07] {2221} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 05-23 19:03:07] {2394} INFO -  at 6.1s,	estimator rf's best error=0.6447,	best estimator lgbm's best error=0.5304
# [flaml.automl.logger: 05-23 19:03:07] {2221} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:09] {2394} INFO -  at 8.6s,	estimator lgbm's best error=0.4719,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:09] {2221} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:09] {2394} INFO -  at 8.8s,	estimator lgbm's best error=0.4719,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:09] {2221} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:10] {2394} INFO -  at 9.1s,	estimator xgboost's best error=0.5968,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:10] {2221} INFO - iteration 58, current learner rf
# [flaml.automl.logger: 05-23 19:03:10] {2394} INFO -  at 9.2s,	estimator rf's best error=0.6447,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:10] {2221} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 05-23 19:03:10] {2394} INFO -  at 9.3s,	estimator rf's best error=0.6145,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:10] {2221} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 05-23 19:03:10] {2394} INFO -  at 9.4s,	estimator rf's best error=0.6145,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:10] {2221} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:12] {2394} INFO -  at 11.4s,	estimator lgbm's best error=0.4719,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:12] {2221} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:12] {2394} INFO -  at 11.5s,	estimator xgboost's best error=0.5968,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:12] {2221} INFO - iteration 63, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:14] {2394} INFO -  at 13.7s,	estimator lgbm's best error=0.4719,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:14] {2221} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:15] {2394} INFO -  at 14.2s,	estimator xgboost's best error=0.5901,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:15] {2221} INFO - iteration 65, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:15] {2394} INFO -  at 14.3s,	estimator xgb_limitdepth's best error=0.5627,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:15] {2221} INFO - iteration 66, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:17] {2394} INFO -  at 16.1s,	estimator lgbm's best error=0.4719,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:17] {2221} INFO - iteration 67, current learner rf
# [flaml.automl.logger: 05-23 19:03:17] {2394} INFO -  at 16.2s,	estimator rf's best error=0.6116,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:17] {2221} INFO - iteration 68, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:17] {2394} INFO -  at 16.5s,	estimator xgb_limitdepth's best error=0.5627,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:17] {2221} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 05-23 19:03:17] {2394} INFO -  at 16.8s,	estimator xgboost's best error=0.5901,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:17] {2221} INFO - iteration 70, current learner lgbm
# [flaml.automl.logger: 05-23 19:03:20] {2394} INFO -  at 19.1s,	estimator lgbm's best error=0.4719,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:20] {2221} INFO - iteration 71, current learner xgb_limitdepth
# [flaml.automl.logger: 05-23 19:03:21] {2394} INFO -  at 20.0s,	estimator xgb_limitdepth's best error=0.5627,	best estimator lgbm's best error=0.4719
# [flaml.automl.logger: 05-23 19:03:23] {2630} INFO - retrain lgbm for 2.2s
# [flaml.automl.logger: 05-23 19:03:23] {2633} INFO - retrained model: LGBMRegressor(learning_rate=0.1096265656053191, max_bin=1023,
#               min_child_samples=24, n_estimators=179, num_leaves=416,
#               reg_alpha=0.002826104794043855, reg_lambda=0.028971420439818363,
#               verbose=-1)
# [flaml.automl.logger: 05-23 19:03:23] {1941} INFO - fit succeeded
# [flaml.automl.logger: 05-23 19:03:23] {1942} INFO - Time taken to find the best model: 8.555925130844116

# %%
# save the AutoML model
import pickle
with open('automl_MAN3.pkl', 'wb') as f:
    pickle.dump(automl.model, f, pickle.HIGHEST_PROTOCOL)

# %%
# read the model parameters and details
best_params = automl.best_config
print("Best Model Parameters:", best_params)
best_model_type = automl.best_estimator
print("Best Model Type:", best_model_type)
# Out:
# Best Model Parameters: {'n_estimators': 179, 'num_leaves': 416, 'min_child_samples': 24, 'learning_rate': 0.1096265656053191, 'log_max_bin': 10, 'colsample_bytree': 1.0, 'reg_alpha': 0.002826104794043855, 'reg_lambda': 0.028971420439818363}
# Best Model Type: lgbm

# %% [markdown]
# # SHapley Additive exPlanations (SHAP)

# %% [markdown]
# SHAP (SHapley Additive exPlanations) analysis is a method used to explain the output of machine learning models, particularly for complex models such as deep learning and ensemble algorithms. The main goal of SHAP analysis is to provide an understandable and interpretable representation of how the features of an input instance contribute to the model's prediction.
#
# SHAP analysis is based on the concept of Shapley values, which originated from cooperative game theory. Shapley values provide a way to fairly distribute a total value among multiple contributors, based on their individual contributions. Shapley values are a concept originating from cooperative game theory, proposed by Lloyd Shapley in 1953. They provide a method for fairly allocating the gains or costs of a cooperative game among its players, taking into account their individual contributions. The Shapley value has several desirable properties, such as efficiency, symmetry, dummy player property, and additivity.
#
# In the context of machine learning, Shapley values are used to allocate the contribution of each feature to the model's prediction for a specific instance. The main idea is to treat the features as players in a cooperative game, where the "gain" is the difference between the prediction for the instance and the average prediction for the entire dataset.
#
# Here's a more detailed explanation of the Shapley value calculation for a machine learning model:
#
# 1.Consider all possible subsets of features, including the empty set and the set with all features. For a model with n features, there are 2^n possible subsets.
#
# 2.For each subset, evaluate the model's prediction using only the features in that subset. For features not in the subset, use a reference value, such as the feature's mean or median value from the dataset.
#
# 3.Calculate the marginal contribution of each feature by comparing the prediction of a subset that includes the feature with the prediction of the same subset without the feature.
#
# 4.Compute the Shapley value for each feature by taking the weighted average of its marginal contributions across all possible subsets. The weight for each subset is given by the formula:
# Weight = (|S|!(n-|S|-1)!)/(n!)
# where |S| is the number of features in subset S, and n is the total number of features. The Shapley values have some key properties that make them suitable for explaining machine learning models:
#
#     a) Efficiency: The sum of the Shapley values for all features equals the total gain, which is the difference between the model's prediction for the instance and the average prediction for the entire dataset.
#
#     b) Symmetry: If two features contribute equally to the model's prediction, they will have the same Shapley value.
#
#     c) Dummy player property: If a feature has no impact on the prediction, its Shapley value will be zero.
#
#     d) Additivity: If the gains from two different cooperative games can be combined, the Shapley values of the combined game will be the sum of the Shapley values of the individual games.
#
# By using Shapley values, we can fairly allocate the contributions of each feature to the model's prediction and provide an interpretable explanation for complex machine learning models.
#
# One of the fundemental properties of Shapley values is that they always sum up to the difference between the game outcome when all players are present and the game outcome when no players are present. For machine learning models this means that SHAP values of all the input features will always sum up to the difference between baseline (expected) model output and the current model output for the prediction being explained.

# %%
import shap

# %%
# run the SHAP analysis
explainer = shap.Explainer(automl.model.estimator)
shap_values = explainer(X1)

# %%
# SHAP can tell us the feature importance
import matplotlib.pyplot as plt
plt.figure()
shap.plots.beeswarm(shap_values,show = False)
# plt.tight_layout()
plt.gcf().set_size_inches(10,8)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
# plt.ylabel(fontsize=12, fontweight='bold', fontproperties='Times New Roman')
plt.tight_layout()
plt.show()
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# We can also use the internal depedency plot of the SHAP package to visualise the dependency on our regressed variable, on any features. In the plot below, we can visualise the joint dependency on temperature and RH. Notice how, in this function call, we pass the value of  interaction_index . In this case we set this to 'r', the name of the column that represents relative humidity.

# %%
shap.dependence_plot("temp", shap_values.values, X1, interaction_index="r")

# %%
shap.dependence_plot("sp", shap_values.values, X1, interaction_index="blh")

# %%
# we also can use SHAP to visualise the model decision process 
sh = explainer.shap_values(X1)
expected_value = explainer.expected_value
feature_names = X1.columns.tolist()
shap.decision_plot(expected_value, sh, X1, feature_order="hclust", return_objects=True, feature_names=feature_names,
                   ignore_warnings=True)
